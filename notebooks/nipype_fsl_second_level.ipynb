# %% [markdown]
# # Second level GLM using Nipype FSL
#
# Notebook compiled by Yibei Chen
#
# In this notebook, we recreate the second-level GLM of FSL GUI using nipype code. For each nipype node, we list the corresponding fsl command from the log file. The dataset we use is a Flanker task, which can be downloaded [here](https://openneuro.org/datasets/ds000102/versions/00001).
#
# We also borrow some helps from this [document](https://nipype.readthedocs.io/en/latest/users/examples/fmri_fsl.html).

# %% [markdown]
# ## Preparation
# Import all the relevant libraries needed for the preprocessing stage.

# %%
from __future__ import print_function
from __future__ import division
from builtins import str
from builtins import range

import os, stat  # system functions
import getpass
from glob import glob

import numpy as np
from nipype import Function
import nipype.interfaces.io as nio  # Data i/o
import nipype.interfaces.fsl as fsl  # fsl
import nipype.interfaces.utility as util  # utility
import nipype.pipeline.engine as pe  # pypeline engine
import nipype.algorithms.modelgen as model  # model generation
import nipype.algorithms.rapidart as ra  # artifact detection

# %autosave 5
# Out:
# 220124-01:11:17,656 nipype.utils WARNING:
# 	 A newer version (1.7.0) of nipy/nipype is available. You are using 1.6.1
# Autosaving every 5 seconds

# %% [markdown]
# Set up data path

# %%
# Get current user
user = getpass.getuser()
print('Running code as: ', user)

# Input: Set the first-level result path
data_dir = '/home/{}/out/fsl/hw2/level1_results/'.format(user)
# Output: Set path where nipype will store stepwise results
exp_dir = '/home/{}/out/fsl/hw2/'.format(user)

try:
    os.mkdir(exp_dir)
except OSError as error:
    print(error)
    
    
# Grant root write access to our output files 
os.chmod(exp_dir, os.stat(exp_dir).st_mode | ((stat.S_IRWXU | stat.S_IRWXO)))
# Out:
# Running code as:  yc
# [Errno 17] File exists: '/home/yc/out/fsl/hw2/'

# %% [markdown]
# Start the workflow

# %%
wf = pe.Workflow(name='level2', base_dir=exp_dir)
wf.config["execution"]["crashfile_format"] = "txt"

# %% [markdown]
# The following two nodes (`infosource` & `dg`) together define all inputs required for the preprocessing workflow

# %%
# we want to group the outcome by contrast not subject
contr_list = [1,2,3,4]
infosource = pe.Node(util.IdentityInterface(fields=["contr_id"]),
                  name="infosource")
infosource.iterables = [("contr_id", contr_list)]

# %%
# here we use SelectFiles, instead of DataGrabber, because the former is more flexible with formatting syntax
templates = {
    "reg_copes":"*/reg_copes/*/*/cope{contr_id}_flirt.nii.gz",
    "reg_varcopes":"*/reg_varcopes/*/*/varcope{contr_id}_flirt.nii.gz",
    "reg_masks":"*/reg_masks/*/*/*.nii.gz"
}
dg = pe.Node(interface=nio.SelectFiles(templates),
             name="selectfiles")
dg.inputs.base_directory = data_dir

wf.connect([
        (infosource, dg, [("contr_id", "contr_id")])
])

# %% [markdown]
# ## Second-level GLM
#
# Combining results from multiple runs of one subject into one

# %% [markdown]
# ### Higher-level input files preparation

# %% [markdown]
# #### Step 1: Merge registered copes & varcopes & masks
#
#
# **Corresponding FSL command:**
# ```
# /usr/local/fsl/bin/fslmerge -t mask (masks from all 52 inputs)
# /usr/local/fsl/bin/fslmerge -t cope (copes from all 52 inputs)
# /usr/local/fsl/bin/fslmerge -t varcop (varcopes from all 52 inputs)
# ```

# %%
copemerge = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="copemerge")

varcopemerge = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="varcopemerge")

maskmerge = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="maskmerge")


def sort_copes(files):
    numelements = len(files[0])
    outfiles = []
    for i in range(numelements):
        outfiles.insert(i, [])
        for j, elements in enumerate(files):
            outfiles[i].append(elements[i])
    return outfiles



wf.connect(dg, 'reg_copes', copemerge, 'in_files')
wf.connect(dg, 'reg_varcopes', varcopemerge, 'in_files')
wf.connect(dg, 'reg_masks', maskmerge, 'in_files')

# %% [markdown]
# #### Step 2: Making mask
#
# In FSL, there are many commands about `maskunique`, which is unless for the second level. We can ignore it.
#
# **Corresponding FSL command:**
# ```
# /usr/local/fsl/bin/fslmaths mask -Tmin mask
# ```

# %%
# /usr/local/fsl/bin/fslmaths mask -Tmin mask
minmask = pe.Node(
    interface=fsl.ImageMaths(op_string='-Tmin'),
    iterfield=['in_file'],
    name='minmask')

wf.connect(maskmerge, 'merged_file', minmask, 'in_file')

# %% [markdown]
# #### Step 3: Masking copes & varcopes
#
# **Corresponding FSL command:**
#
# we have four contrasts so the following commands repeat four times
#
# ```
# /usr/local/fsl/bin/fslmaths cope1 -mas mask cope1
# /usr/local/fsl/bin/fslmaths varcope1 -mas mask varcope1
# ```

# %%
maskcope = pe.Node(
    interface=fsl.ImageMaths(op_string='-mas'),
    iterfield=['in_file', 'in_file2'],
    name='maskcope')

maskvarcope = pe.Node(
    interface=fsl.ImageMaths(op_string='-mas'),
    iterfield=['in_file', 'in_file2'],
    name='maskvarcope')

wf.connect(copemerge, 'merged_file', maskcope, 'in_file')
wf.connect(minmask, 'out_file', maskcope, 'in_file2')
wf.connect(varcopemerge, 'merged_file', maskvarcope, 'in_file')
wf.connect(minmask, 'out_file', maskvarcope, 'in_file2')

# %% [markdown]
# ### Set up second-level contrasts and fixed-effects

# %%
def get_contrasts_l2(in_files):
    import numpy as np
    total = len(in_files)
    print(in_files)
    print(total)
    n_sub = 26
    ev_list = ['ev'+str(x) for x in range(1,n_sub+1)]
    weight_mtx = np.zeros((26,26))
    weight_mtx = weight_mtx.astype(np.float64)
    np.fill_diagonal(weight_mtx,1.)
    contr = ['','T',ev_list,list(weight_mtx[0])]
    contr_lst = np.tile(contr, (n_sub, 1))
    contr_lst = [list(x) for x in contr_lst]
    for i in range(n_sub):
        contr_lst[i][3] = list(weight_mtx[i])

    reg_dict = {k:None for k in ev_list}
    for k in reg_dict.keys():
        start_lst = [0.0] * total
        idx = ev_list.index(k)
        start_idx = idx*2
        end_idx = idx*2 + 1
        start_lst[start_idx] = 1.
        start_lst[end_idx] = 1.
        reg_dict[k] = start_lst
        
    return contr_lst, reg_dict

contrastgen_l2 = pe.Node(util.Function(input_names=['in_files'],
                                    output_names=['contr_lst', 'reg_dict'],
                                    function=get_contrasts_l2),
                      iterfield=['in_files'],
                      name='contrastgen_l2')

wf.connect(dg,'reg_copes', contrastgen_l2, 'in_files')

# %% [markdown]
# Nipype recommands using [L2Model](https://nipype.readthedocs.io/en/latest/api/generated/nipype.interfaces.fsl.model.html#l2model), which only works for the single subject. It takes the number of runs (copes at the first level) as input and does estimations for subject one by one.
# Instead, we use [MultipleRegressDesign](https://nipype.readthedocs.io/en/latest/api/generated/nipype.interfaces.fsl.model.html#multipleregressdesign). As it's name indicates, this one can deal with multiple predictors (subjects) at the same time.

# %%
level2model = pe.Node(interface=fsl.MultipleRegressDesign(),
                      name='l2model')

wf.connect([(contrastgen_l2, level2model, [('contr_lst','contrasts'),
                                        ('reg_dict','regressors')])])

# %%
level2estimate = pe.Node(
    interface=fsl.FLAMEO(run_mode='fe'),
    name="level2estimate",
    iterfield=['cope_file', 'var_cope_file'])

wf.connect([
    (maskcope, level2estimate, [('out_file', 'cope_file')]),
    (maskvarcope, level2estimate, [('out_file', 'var_cope_file')]),
    (minmask, level2estimate, [('out_file', 'mask_file')]),
    (level2model, level2estimate, [('design_mat', 'design_file'),
                                   ('design_con', 't_con_file'), 
                                   ('design_grp', 'cov_split_file')]),
])

# %%
datasink = pe.Node(nio.DataSink(), name='sinker')
datasink.inputs.base_directory=os.path.join(exp_dir, "level2_results")

int2string = lambda x: 'contrast_'+str(x)
    
wf.connect(infosource, ('contr_id',int2string), datasink, 'container')
wf.connect([(level2estimate, datasink, [('stats_dir', 'stats_dir')])])

# %%
# Run Workflow
wf.run(plugin="MultiProc", plugin_args={"n_procs": 8})
# Out:
# 220124-01:11:18,165 nipype.workflow INFO:
# 	 Workflow level2 settings: ['check', 'execution', 'logging', 'monitoring']
# 220124-01:11:18,199 nipype.workflow INFO:
# 	 Running in parallel.
# 220124-01:11:18,202 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 27.96/27.96, Free processors: 8/8.
# 220124-01:11:18,276 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles" in "/home/yc/out/fsl/hw2/level2/_contr_id_4/selectfiles".
# 220124-01:11:18,277 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles" in "/home/yc/out/fsl/hw2/level2/_contr_id_3/selectfiles".
# 220124-01:11:18,278 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles" in "/home/yc/out/fsl/hw2/level2/_contr_id_1/selectfiles".
# 220124-01:11:18,278 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles" in "/home/yc/out/fsl/hw2/level2/_contr_id_2/selectfiles".
# 220124-01:11:18,287 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 220124-01:11:18,289 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 220124-01:11:18,289 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 220124-01:11:18,292 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 220124-01:11:18,453 nipype.workflow INFO:
# 	 [Node] Finished "level2.selectfiles".
# 220124-01:11:18,452 nipype.workflow INFO:
# 	 [Node] Finished "level2.selectfiles".
# 220124-01:11:18,453 nipype.workflow INFO:
# 	 [Node] Finished "level2.selectfiles".
# 220124-01:11:18,503 nipype.workflow INFO:
# 	 [Node] Finished "level2.selectfiles".
# 220124-01:11:20,203 nipype.workflow INFO:
# 	 [Job 0] Completed (level2.selectfiles).
# 220124-01:11:20,205 nipype.workflow INFO:
# 	 [Job 11] Completed (level2.selectfiles).
# 220124-01:11:20,206 nipype.workflow INFO:
# 	 [Job 22] Completed (level2.selectfiles).
# 220124-01:11:20,207 nipype.workflow INFO:
# 	 [Job 33] Completed (level2.selectfiles).
# 220124-01:11:20,208 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 16 jobs ready. Free memory (GB): 27.96/27.96, Free processors: 8/8.
# 220124-01:11:20,266 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.contrastgen_l2" in "/home/yc/out/fsl/hw2/level2/_contr_id_4/contrastgen_l2".
# 220124-01:11:20,269 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.contrastgen_l2" in "/home/yc/out/fsl/hw2/level2/_contr_id_3/contrastgen_l2".
# 220124-01:11:20,270 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskmerge" in "/home/yc/out/fsl/hw2/level2/_contr_id_3/maskmerge".
# 220124-01:11:20,271 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.copemerge" in "/home/yc/out/fsl/hw2/level2/_contr_id_3/copemerge".
# 220124-01:11:20,271 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.varcopemerge" in "/home/yc/out/fsl/hw2/level2/_contr_id_3/varcopemerge".
# 220124-01:11:20,284 nipype.workflow INFO:
# 	 [Node] Running "contrastgen_l2" ("nipype.interfaces.utility.wrappers.Function")
# 220124-01:11:20,285 nipype.workflow INFO:
# 	 [Node] Running "contrastgen_l2" ("nipype.interfaces.utility.wrappers.Function")
# ['/home/yc/out/fsl/hw2/level1_results/01/reg_copes/_subject_id_01/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/02/reg_copes/_subject_id_02/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/02/reg_copes/_subject_id_02/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/03/reg_copes/_subject_id_03/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/03/reg_copes/_subject_id_03/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/04/reg_copes/_subject_id_04/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/04/reg_copes/_subject_id_04/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/05/reg_copes/_subject_id_05/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/05/reg_copes/_subject_id_05/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/06/reg_copes/_subject_id_06/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/06/reg_copes/_subject_id_06/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/07/reg_copes/_subject_id_07/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/07/reg_copes/_subject_id_07/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/08/reg_copes/_subject_id_08/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/08/reg_copes/_subject_id_08/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/09/reg_copes/_subject_id_09/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/09/reg_copes/_subject_id_09/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/10/reg_copes/_subject_id_10/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/10/reg_copes/_subject_id_10/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/11/reg_copes/_subject_id_11/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/11/reg_copes/_subject_id_11/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/12/reg_copes/_subject_id_12/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/12/reg_copes/_subject_id_12/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/13/reg_copes/_subject_id_13/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/13/reg_copes/_subject_id_13/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/14/reg_copes/_subject_id_14/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/14/reg_copes/_subject_id_14/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/15/reg_copes/_subject_id_15/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/15/reg_copes/_subject_id_15/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/16/reg_copes/_subject_id_16/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/16/reg_copes/_subject_id_16/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/17/reg_copes/_subject_id_17/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/17/reg_copes/_subject_id_17/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/18/reg_copes/_subject_id_18/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/18/reg_copes/_subject_id_18/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/19/reg_copes/_subject_id_19/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/19/reg_copes/_subject_id_19/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/20/reg_copes/_subject_id_20/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/20/reg_copes/_subject_id_20/_warpfunc1/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/level1_results/21/reg_copes/_subject_id_21/_warpfunc0/cope3_flirt.nii.gz', '/home/yc/out/fsl/hw2/ ...
#
# 52
# 220124-01:11:20,291 nipype.workflow INFO:
# 	 [Node] Running "copemerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t cope3_flirt_merged.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_copes/_subject_id_01/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_copes/_subject_id_02/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_copes/_subject_id_02/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_copes/_subject_id_03/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_copes/_subject_id_03/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_copes/_subject_id_04/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_copes/_subject_id_04/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_copes/_subject_id_05/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_copes/_subject_id_05/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_copes/_subject_id_06/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_copes/_subject_id_06/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_copes/_subject_id_07/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_copes/_subject_id_07/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_copes/_subject_id_08/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_copes/_subject_id_08/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_copes/_subject_id_09/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_copes/_subject_id_09/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_copes/_subject_id_10/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_copes/_subject_id_10/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_copes/_subject_id_11/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_copes/_subject_id_11/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_copes/_subject_id_12/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_copes/_subject_id_12/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_copes/_subject_id_13/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_copes/_subject_id_13/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_copes/_subject_id_14/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_copes/_subject_id_14/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/15/reg_copes/_subject_id_15/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/15/reg_copes/_subject_id_15/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/16/reg_copes/_subject_id_16/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/16/reg_copes/_subject_id_16/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/17/reg_copes/_subject_id_17/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/17/reg_copes/_subject_id_17/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/18/reg_copes/_subject_id_18/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/18/reg_copes/_subject_id_18/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/19/reg_copes/_subject_id_19/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/19/reg_copes/_subject_id_19/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/20/reg_copes/_subject_id_20/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/20/reg_copes/_subject_id_20/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/21/reg_copes/_subject_id_21/_warpfunc0/cope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/21/reg_copes/_subject_id_21/_warpfunc1/cope3_flirt.nii.gz /home/yc/out/f ...
# /opt/miniconda-latest/envs/neuro/lib/python3.7/site-packages/numpy/lib/shape_base.py:1250: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   c = _nx.array(A, copy=False, subok=True, ndmin=d)
# 52
# 220124-01:11:20,294 nipype.workflow INFO:
# 	 [Node] Running "maskmerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_masks/_subject_id_01/_warpfunc0/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_masks/_subject_id_01/_warpfunc1/sub-01_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_masks/_subject_id_02/_warpfunc0/sub-02_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_masks/_subject_id_02/_warpfunc1/sub-02_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_masks/_subject_id_03/_warpfunc0/sub-03_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_masks/_subject_id_03/_warpfunc1/sub-03_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_masks/_subject_id_04/_warpfunc0/sub-04_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_masks/_subject_id_04/_warpfunc1/sub-04_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_masks/_subject_id_05/_warpfunc0/sub-05_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_masks/_subject_id_05/_warpfunc1/sub-05_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_masks/_subject_id_06/_warpfunc0/sub-06_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_masks/_subject_id_06/_warpfunc1/sub-06_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_masks/_subject_id_07/_warpfunc0/sub-07_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_masks/_subject_id_07/_warpfunc1/sub-07_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_masks/_subject_id_08/_warpfunc0/sub-08_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_masks/_subject_id_08/_warpfunc1/sub-08_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_masks/_subject_id_09/_warpfunc0/sub-09_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_masks/_subject_id_09/_warpfunc1/sub-09_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_masks/_subject_id_10/_warpfunc0/sub-10_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_masks/_subject_id_10/_warpfunc1/sub-10_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_masks/_subject_id_11/_warpfunc0/sub-11_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_masks/_subject_id_11/_warpfunc1/sub-11_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_masks/_subject_id_12/_warpfunc0/sub-12_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_masks/_subject_id_12/_warpfunc1/sub-12_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_masks/_subject_id_13/_warpfunc0/sub-13_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_masks/_subject_id_13/_warpfunc1/sub-13_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_masks/_subject_id_14/_warpfunc0/sub-14_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/lev ...
# 220124-01:11:20,294 nipype.workflow INFO:
# 	 [Node] Running "varcopemerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t varcope3_flirt_merged.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_varcopes/_subject_id_01/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_varcopes/_subject_id_01/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_varcopes/_subject_id_02/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_varcopes/_subject_id_02/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_varcopes/_subject_id_03/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_varcopes/_subject_id_03/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_varcopes/_subject_id_04/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_varcopes/_subject_id_04/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_varcopes/_subject_id_05/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_varcopes/_subject_id_05/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_varcopes/_subject_id_06/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_varcopes/_subject_id_06/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_varcopes/_subject_id_07/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_varcopes/_subject_id_07/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_varcopes/_subject_id_08/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_varcopes/_subject_id_08/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_varcopes/_subject_id_09/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_varcopes/_subject_id_09/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_varcopes/_subject_id_10/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_varcopes/_subject_id_10/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_varcopes/_subject_id_11/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_varcopes/_subject_id_11/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_varcopes/_subject_id_12/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_varcopes/_subject_id_12/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_varcopes/_subject_id_13/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_varcopes/_subject_id_13/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_varcopes/_subject_id_14/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_varcopes/_subject_id_14/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/15/reg_varcopes/_subject_id_15/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/15/reg_varcopes/_subject_id_15/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/16/reg_varcopes/_subject_id_16/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/16/reg_varcopes/_subject_id_16/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/17/reg_varcopes/_subject_id_17/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/17/reg_varcopes/_subject_id_17/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/18/reg_varcopes/_subject_id_18/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/18/reg_varcopes/_subject_id_18/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/19/reg_varcopes/_subject_id_19/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/19/reg_varcopes/_subject_id_19/_warpfunc1/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/20/reg_varcopes/_subject_id_20/_warpfunc0/varcope3_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/20/reg_varcopes/_subjec ...
# /opt/miniconda-latest/envs/neuro/lib/python3.7/site-packages/numpy/lib/shape_base.py:1250: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   c = _nx.array(A, copy=False, subok=True, ndmin=d)
# 220124-01:11:20,267 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskmerge" in "/home/yc/out/fsl/hw2/level2/_contr_id_4/maskmerge".
# 220124-01:11:20,268 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.copemerge" in "/home/yc/out/fsl/hw2/level2/_contr_id_4/copemerge".
# 220124-01:11:20,268 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.varcopemerge" in "/home/yc/out/fsl/hw2/level2/_contr_id_4/varcopemerge".
# 220124-01:11:20,324 nipype.workflow INFO:
# 	 [Node] Running "varcopemerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t varcope4_flirt_merged.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_varcopes/_subject_id_01/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_varcopes/_subject_id_01/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_varcopes/_subject_id_02/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_varcopes/_subject_id_02/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_varcopes/_subject_id_03/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_varcopes/_subject_id_03/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_varcopes/_subject_id_04/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_varcopes/_subject_id_04/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_varcopes/_subject_id_05/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_varcopes/_subject_id_05/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_varcopes/_subject_id_06/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_varcopes/_subject_id_06/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_varcopes/_subject_id_07/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_varcopes/_subject_id_07/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_varcopes/_subject_id_08/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_varcopes/_subject_id_08/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_varcopes/_subject_id_09/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_varcopes/_subject_id_09/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_varcopes/_subject_id_10/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_varcopes/_subject_id_10/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_varcopes/_subject_id_11/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_varcopes/_subject_id_11/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_varcopes/_subject_id_12/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_varcopes/_subject_id_12/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_varcopes/_subject_id_13/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_varcopes/_subject_id_13/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_varcopes/_subject_id_14/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_varcopes/_subject_id_14/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/15/reg_varcopes/_subject_id_15/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/15/reg_varcopes/_subject_id_15/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/16/reg_varcopes/_subject_id_16/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/16/reg_varcopes/_subject_id_16/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/17/reg_varcopes/_subject_id_17/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/17/reg_varcopes/_subject_id_17/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/18/reg_varcopes/_subject_id_18/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/18/reg_varcopes/_subject_id_18/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/19/reg_varcopes/_subject_id_19/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/19/reg_varcopes/_subject_id_19/_warpfunc1/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/20/reg_varcopes/_subject_id_20/_warpfunc0/varcope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/20/reg_varcopes/_subjec ...
# 220124-01:11:20,324 nipype.workflow INFO:
# 	 [Node] Running "maskmerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_masks/_subject_id_01/_warpfunc0/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_masks/_subject_id_01/_warpfunc1/sub-01_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_masks/_subject_id_02/_warpfunc0/sub-02_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_masks/_subject_id_02/_warpfunc1/sub-02_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_masks/_subject_id_03/_warpfunc0/sub-03_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_masks/_subject_id_03/_warpfunc1/sub-03_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_masks/_subject_id_04/_warpfunc0/sub-04_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_masks/_subject_id_04/_warpfunc1/sub-04_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_masks/_subject_id_05/_warpfunc0/sub-05_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_masks/_subject_id_05/_warpfunc1/sub-05_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_masks/_subject_id_06/_warpfunc0/sub-06_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_masks/_subject_id_06/_warpfunc1/sub-06_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_masks/_subject_id_07/_warpfunc0/sub-07_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_masks/_subject_id_07/_warpfunc1/sub-07_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_masks/_subject_id_08/_warpfunc0/sub-08_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_masks/_subject_id_08/_warpfunc1/sub-08_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_masks/_subject_id_09/_warpfunc0/sub-09_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_masks/_subject_id_09/_warpfunc1/sub-09_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_masks/_subject_id_10/_warpfunc0/sub-10_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_masks/_subject_id_10/_warpfunc1/sub-10_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_masks/_subject_id_11/_warpfunc0/sub-11_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_masks/_subject_id_11/_warpfunc1/sub-11_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_masks/_subject_id_12/_warpfunc0/sub-12_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_masks/_subject_id_12/_warpfunc1/sub-12_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_masks/_subject_id_13/_warpfunc0/sub-13_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_masks/_subject_id_13/_warpfunc1/sub-13_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_masks/_subject_id_14/_warpfunc0/sub-14_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/lev ...
# 220124-01:11:20,325 nipype.workflow INFO:
# 	 [Node] Running "copemerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t cope4_flirt_merged.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_copes/_subject_id_01/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_copes/_subject_id_02/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_copes/_subject_id_02/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_copes/_subject_id_03/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_copes/_subject_id_03/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_copes/_subject_id_04/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_copes/_subject_id_04/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_copes/_subject_id_05/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_copes/_subject_id_05/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_copes/_subject_id_06/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_copes/_subject_id_06/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_copes/_subject_id_07/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_copes/_subject_id_07/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_copes/_subject_id_08/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_copes/_subject_id_08/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_copes/_subject_id_09/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_copes/_subject_id_09/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_copes/_subject_id_10/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_copes/_subject_id_10/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_copes/_subject_id_11/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_copes/_subject_id_11/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_copes/_subject_id_12/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_copes/_subject_id_12/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_copes/_subject_id_13/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_copes/_subject_id_13/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_copes/_subject_id_14/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_copes/_subject_id_14/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/15/reg_copes/_subject_id_15/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/15/reg_copes/_subject_id_15/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/16/reg_copes/_subject_id_16/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/16/reg_copes/_subject_id_16/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/17/reg_copes/_subject_id_17/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/17/reg_copes/_subject_id_17/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/18/reg_copes/_subject_id_18/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/18/reg_copes/_subject_id_18/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/19/reg_copes/_subject_id_19/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/19/reg_copes/_subject_id_19/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/20/reg_copes/_subject_id_20/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/20/reg_copes/_subject_id_20/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/21/reg_copes/_subject_id_21/_warpfunc0/cope4_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/21/reg_copes/_subject_id_21/_warpfunc1/cope4_flirt.nii.gz /home/yc/out/f ...
# 220124-01:11:20,345 nipype.workflow INFO:
# 	 [Node] Finished "level2.contrastgen_l2".
# 220124-01:11:20,345 nipype.workflow INFO:
# 	 [Node] Finished "level2.contrastgen_l2".
# 220124-01:11:21,581 nipype.workflow INFO:
# 	 [Node] Finished "level2.maskmerge".
# 220124-01:11:21,582 nipype.workflow INFO:
# 	 [Node] Finished "level2.maskmerge".
# 220124-01:11:22,204 nipype.workflow INFO:
# 	 [Job 1] Completed (level2.contrastgen_l2).
# 220124-01:11:22,206 nipype.workflow INFO:
# 	 [Job 3] Completed (level2.maskmerge).
# 220124-01:11:22,207 nipype.workflow INFO:
# 	 [Job 12] Completed (level2.contrastgen_l2).
# 220124-01:11:22,208 nipype.workflow INFO:
# 	 [Job 14] Completed (level2.maskmerge).
# 220124-01:11:22,209 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 12 jobs ready. Free memory (GB): 27.16/27.96, Free processors: 4/8.
#                      Currently running:
#                        * level2.copemerge
#                        * level2.varcopemerge
#                        * level2.copemerge
#                        * level2.varcopemerge
# 220124-01:11:22,257 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.l2model" in "/home/yc/out/fsl/hw2/level2/_contr_id_4/l2model".
# 220124-01:11:22,261 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.minmask" in "/home/yc/out/fsl/hw2/level2/_contr_id_4/minmask".
# 220124-01:11:22,265 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.l2model" in "/home/yc/out/fsl/hw2/level2/_contr_id_3/l2model".
# 220124-01:11:22,269 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.minmask" in "/home/yc/out/fsl/hw2/level2/_contr_id_3/minmask".
# 220124-01:11:22,374 nipype.workflow INFO:
# 	 [Node] Running "minmask" ("nipype.interfaces.fsl.utils.ImageMaths"), a CommandLine Interface with command:
# fslmaths /home/yc/out/fsl/hw2/level2/_contr_id_4/maskmerge/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged.nii.gz -Tmin /home/yc/out/fsl/hw2/level2/_contr_id_4/minmask/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged_maths.nii.gz
# 220124-01:11:22,376 nipype.workflow INFO:
# 	 [Node] Running "minmask" ("nipype.interfaces.fsl.utils.ImageMaths"), a CommandLine Interface with command:
# fslmaths /home/yc/out/fsl/hw2/level2/_contr_id_3/maskmerge/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged.nii.gz -Tmin /home/yc/out/fsl/hw2/level2/_contr_id_3/minmask/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged_maths.nii.gz
# 220124-01:11:22,398 nipype.workflow INFO:
# 	 [Node] Running "l2model" ("nipype.interfaces.fsl.model.MultipleRegressDesign")
# 220124-01:11:22,412 nipype.workflow INFO:
# 	 [Node] Running "l2model" ("nipype.interfaces.fsl.model.MultipleRegressDesign")
# 220124-01:11:22,542 nipype.workflow INFO:
# 	 [Node] Finished "level2.l2model".
# 220124-01:11:22,545 nipype.workflow INFO:
# 	 [Node] Finished "level2.l2model".
# 220124-01:11:23,938 nipype.workflow INFO:
# 	 [Node] Finished "level2.minmask".
# 220124-01:11:24,206 nipype.workflow INFO:
# 	 [Job 2] Completed (level2.l2model).
# 220124-01:11:24,208 nipype.workflow INFO:
# 	 [Job 13] Completed (level2.l2model).
# 220124-01:11:24,208 nipype.workflow INFO:
# 	 [Job 15] Completed (level2.minmask).
# 220124-01:11:24,210 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 8 jobs ready. Free memory (GB): 26.96/27.96, Free processors: 3/8.
#                      Currently running:
#                        * level2.minmask
#                        * level2.copemerge
#                        * level2.varcopemerge
#                        * level2.copemerge
#                        * level2.varcopemerge
# 220124-01:11:24,373 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.contrastgen_l2" in "/home/yc/out/fsl/hw2/level2/_contr_id_2/contrastgen_l2".
# 220124-01:11:24,498 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskmerge" in "/home/yc/out/fsl/hw2/level2/_contr_id_2/maskmerge".
# 220124-01:11:24,623 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.varcopemerge" in "/home/yc/out/fsl/hw2/level2/_contr_id_2/varcopemerge".
# 220124-01:11:26,209 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 5 jobs ready. Free memory (GB): 26.36/27.96, Free processors: 0/8.
#                      Currently running:
#                        * level2.varcopemerge
#                        * level2.maskmerge
#                        * level2.contrastgen_l2
#                        * level2.minmask
#                        * level2.copemerge
#                        * level2.varcopemerge
#                        * level2.copemerge
#                        * level2.varcopemerge
# 220124-01:11:26,721 nipype.workflow INFO:
# 	 [Node] Finished "level2.minmask".
# 220124-01:11:26,739 nipype.workflow INFO:
# 	 [Node] Finished "level2.copemerge".
# 220124-01:11:26,744 nipype.workflow INFO:
# 	 [Node] Running "contrastgen_l2" ("nipype.interfaces.utility.wrappers.Function")
# 220124-01:11:26,752 nipype.workflow INFO:
# 	 [Node] Running "varcopemerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t varcope2_flirt_merged.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_varcopes/_subject_id_01/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_varcopes/_subject_id_01/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_varcopes/_subject_id_02/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_varcopes/_subject_id_02/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_varcopes/_subject_id_03/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_varcopes/_subject_id_03/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_varcopes/_subject_id_04/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_varcopes/_subject_id_04/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_varcopes/_subject_id_05/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_varcopes/_subject_id_05/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_varcopes/_subject_id_06/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_varcopes/_subject_id_06/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_varcopes/_subject_id_07/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_varcopes/_subject_id_07/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_varcopes/_subject_id_08/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_varcopes/_subject_id_08/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_varcopes/_subject_id_09/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_varcopes/_subject_id_09/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_varcopes/_subject_id_10/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_varcopes/_subject_id_10/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_varcopes/_subject_id_11/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_varcopes/_subject_id_11/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_varcopes/_subject_id_12/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_varcopes/_subject_id_12/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_varcopes/_subject_id_13/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_varcopes/_subject_id_13/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_varcopes/_subject_id_14/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_varcopes/_subject_id_14/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/15/reg_varcopes/_subject_id_15/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/15/reg_varcopes/_subject_id_15/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/16/reg_varcopes/_subject_id_16/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/16/reg_varcopes/_subject_id_16/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/17/reg_varcopes/_subject_id_17/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/17/reg_varcopes/_subject_id_17/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/18/reg_varcopes/_subject_id_18/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/18/reg_varcopes/_subject_id_18/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/19/reg_varcopes/_subject_id_19/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/19/reg_varcopes/_subject_id_19/_warpfunc1/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/20/reg_varcopes/_subject_id_20/_warpfunc0/varcope2_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/20/reg_varcopes/_subjec ...
# 220124-01:11:26,752 nipype.workflow INFO:
# 	 [Node] Running "maskmerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_masks/_subject_id_01/_warpfunc0/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_masks/_subject_id_01/_warpfunc1/sub-01_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_masks/_subject_id_02/_warpfunc0/sub-02_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_masks/_subject_id_02/_warpfunc1/sub-02_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_masks/_subject_id_03/_warpfunc0/sub-03_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_masks/_subject_id_03/_warpfunc1/sub-03_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_masks/_subject_id_04/_warpfunc0/sub-04_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_masks/_subject_id_04/_warpfunc1/sub-04_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_masks/_subject_id_05/_warpfunc0/sub-05_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_masks/_subject_id_05/_warpfunc1/sub-05_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_masks/_subject_id_06/_warpfunc0/sub-06_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_masks/_subject_id_06/_warpfunc1/sub-06_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_masks/_subject_id_07/_warpfunc0/sub-07_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_masks/_subject_id_07/_warpfunc1/sub-07_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_masks/_subject_id_08/_warpfunc0/sub-08_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_masks/_subject_id_08/_warpfunc1/sub-08_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_masks/_subject_id_09/_warpfunc0/sub-09_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_masks/_subject_id_09/_warpfunc1/sub-09_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_masks/_subject_id_10/_warpfunc0/sub-10_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_masks/_subject_id_10/_warpfunc1/sub-10_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_masks/_subject_id_11/_warpfunc0/sub-11_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_masks/_subject_id_11/_warpfunc1/sub-11_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_masks/_subject_id_12/_warpfunc0/sub-12_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_masks/_subject_id_12/_warpfunc1/sub-12_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_masks/_subject_id_13/_warpfunc0/sub-13_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_masks/_subject_id_13/_warpfunc1/sub-13_task-flanker_run-2_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_masks/_subject_id_14/_warpfunc0/sub-14_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt.nii.gz /home/yc/out/fsl/hw2/lev ...
# ...
# 220124-01:11:38,294 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.fsl.model.FLAMEO"), a CommandLine Interface with command:
# flameo --copefile=/home/yc/out/fsl/hw2/level2/_contr_id_4/maskcope/cope4_flirt_merged_maths.nii.gz --covsplitfile=/home/yc/out/fsl/hw2/level2/_contr_id_4/l2model/design.grp --designfile=/home/yc/out/fsl/hw2/level2/_contr_id_4/l2model/design.mat --ld=stats --maskfile=/home/yc/out/fsl/hw2/level2/_contr_id_4/minmask/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged_maths.nii.gz --runmode=fe --tcontrastsfile=/home/yc/out/fsl/hw2/level2/_contr_id_4/l2model/design.con --varcopefile=/home/yc/out/fsl/hw2/level2/_contr_id_4/maskvarcope/varcope4_flirt_merged_maths.nii.gz
# 220124-01:11:38,300 nipype.workflow INFO:
# 	 [Node] Running "copemerge" ("nipype.interfaces.fsl.utils.Merge"), a CommandLine Interface with command:
# fslmerge -t cope1_flirt_merged.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_copes/_subject_id_01/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/01/reg_copes/_subject_id_01/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_copes/_subject_id_02/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/02/reg_copes/_subject_id_02/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_copes/_subject_id_03/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/03/reg_copes/_subject_id_03/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_copes/_subject_id_04/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/04/reg_copes/_subject_id_04/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_copes/_subject_id_05/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/05/reg_copes/_subject_id_05/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_copes/_subject_id_06/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/06/reg_copes/_subject_id_06/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_copes/_subject_id_07/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/07/reg_copes/_subject_id_07/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_copes/_subject_id_08/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/08/reg_copes/_subject_id_08/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_copes/_subject_id_09/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/09/reg_copes/_subject_id_09/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_copes/_subject_id_10/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/10/reg_copes/_subject_id_10/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_copes/_subject_id_11/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/11/reg_copes/_subject_id_11/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_copes/_subject_id_12/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/12/reg_copes/_subject_id_12/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_copes/_subject_id_13/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/13/reg_copes/_subject_id_13/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_copes/_subject_id_14/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/14/reg_copes/_subject_id_14/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/15/reg_copes/_subject_id_15/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/15/reg_copes/_subject_id_15/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/16/reg_copes/_subject_id_16/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/16/reg_copes/_subject_id_16/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/17/reg_copes/_subject_id_17/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/17/reg_copes/_subject_id_17/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/18/reg_copes/_subject_id_18/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/18/reg_copes/_subject_id_18/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/19/reg_copes/_subject_id_19/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/19/reg_copes/_subject_id_19/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/20/reg_copes/_subject_id_20/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/20/reg_copes/_subject_id_20/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/21/reg_copes/_subject_id_21/_warpfunc0/cope1_flirt.nii.gz /home/yc/out/fsl/hw2/level1_results/21/reg_copes/_subject_id_21/_warpfunc1/cope1_flirt.nii.gz /home/yc/out/f ...
# 220124-01:11:39,696 nipype.workflow INFO:
# 	 [Node] Finished "level2.varcopemerge".
# 220124-01:11:40,220 nipype.workflow INFO:
# 	 [Job 38] Completed (level2.varcopemerge).
# 220124-01:11:40,223 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 27.16/27.96, Free processors: 4/8.
#                      Currently running:
#                        * level2.copemerge
#                        * level2.maskcope
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220124-01:11:40,277 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskvarcope" in "/home/yc/out/fsl/hw2/level2/_contr_id_1/maskvarcope".
# 220124-01:11:40,478 nipype.workflow INFO:
# 	 [Node] Running "maskvarcope" ("nipype.interfaces.fsl.utils.ImageMaths"), a CommandLine Interface with command:
# fslmaths /home/yc/out/fsl/hw2/level2/_contr_id_1/varcopemerge/varcope1_flirt_merged.nii.gz -mas /home/yc/out/fsl/hw2/level2/_contr_id_1/minmask/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged_maths.nii.gz /home/yc/out/fsl/hw2/level2/_contr_id_1/maskvarcope/varcope1_flirt_merged_maths.nii.gz
# 220124-01:11:42,223 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 0 jobs ready. Free memory (GB): 26.96/27.96, Free processors: 3/8.
#                      Currently running:
#                        * level2.maskvarcope
#                        * level2.copemerge
#                        * level2.maskcope
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220124-01:11:42,970 nipype.workflow INFO:
# 	 [Node] Finished "level2.maskcope".
# 220124-01:11:44,223 nipype.workflow INFO:
# 	 [Job 30] Completed (level2.maskcope).
# 220124-01:11:44,225 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 27.16/27.96, Free processors: 4/8.
#                      Currently running:
#                        * level2.maskvarcope
#                        * level2.copemerge
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220124-01:11:44,345 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2estimate" in "/home/yc/out/fsl/hw2/level2/_contr_id_2/level2estimate".
# 220124-01:11:44,971 nipype.workflow INFO:
# 	 [Node] Finished "level2.copemerge".
# 220124-01:11:44,974 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.fsl.model.FLAMEO"), a CommandLine Interface with command:
# flameo --copefile=/home/yc/out/fsl/hw2/level2/_contr_id_2/maskcope/cope2_flirt_merged_maths.nii.gz --covsplitfile=/home/yc/out/fsl/hw2/level2/_contr_id_2/l2model/design.grp --designfile=/home/yc/out/fsl/hw2/level2/_contr_id_2/l2model/design.mat --ld=stats --maskfile=/home/yc/out/fsl/hw2/level2/_contr_id_2/minmask/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged_maths.nii.gz --runmode=fe --tcontrastsfile=/home/yc/out/fsl/hw2/level2/_contr_id_2/l2model/design.con --varcopefile=/home/yc/out/fsl/hw2/level2/_contr_id_2/maskvarcope/varcope2_flirt_merged_maths.nii.gz
# 220124-01:11:45,51 nipype.workflow INFO:
# 	 [Node] Finished "level2.maskvarcope".
# 220124-01:11:46,225 nipype.workflow INFO:
# 	 [Job 40] Completed (level2.copemerge).
# 220124-01:11:46,226 nipype.workflow INFO:
# 	 [Job 39] Completed (level2.maskvarcope).
# 220124-01:11:46,228 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 27.36/27.96, Free processors: 5/8.
#                      Currently running:
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220124-01:11:46,273 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.maskcope" in "/home/yc/out/fsl/hw2/level2/_contr_id_1/maskcope".
# 220124-01:11:46,286 nipype.workflow INFO:
# 	 [Node] Running "maskcope" ("nipype.interfaces.fsl.utils.ImageMaths"), a CommandLine Interface with command:
# fslmaths /home/yc/out/fsl/hw2/level2/_contr_id_1/copemerge/cope1_flirt_merged.nii.gz -mas /home/yc/out/fsl/hw2/level2/_contr_id_1/minmask/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged_maths.nii.gz /home/yc/out/fsl/hw2/level2/_contr_id_1/maskcope/cope1_flirt_merged_maths.nii.gz
# 220124-01:11:48,229 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 27.16/27.96, Free processors: 4/8.
#                      Currently running:
#                        * level2.maskcope
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220124-01:11:49,127 nipype.workflow INFO:
# 	 [Node] Finished "level2.maskcope".
# 220124-01:11:50,228 nipype.workflow INFO:
# 	 [Job 41] Completed (level2.maskcope).
# 220124-01:11:50,230 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 27.36/27.96, Free processors: 5/8.
#                      Currently running:
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220124-01:11:50,281 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2estimate" in "/home/yc/out/fsl/hw2/level2/_contr_id_1/level2estimate".
# 220124-01:11:50,297 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.fsl.model.FLAMEO"), a CommandLine Interface with command:
# flameo --copefile=/home/yc/out/fsl/hw2/level2/_contr_id_1/maskcope/cope1_flirt_merged_maths.nii.gz --covsplitfile=/home/yc/out/fsl/hw2/level2/_contr_id_1/l2model/design.grp --designfile=/home/yc/out/fsl/hw2/level2/_contr_id_1/l2model/design.mat --ld=stats --maskfile=/home/yc/out/fsl/hw2/level2/_contr_id_1/minmask/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged_maths.nii.gz --runmode=fe --tcontrastsfile=/home/yc/out/fsl/hw2/level2/_contr_id_1/l2model/design.con --varcopefile=/home/yc/out/fsl/hw2/level2/_contr_id_1/maskvarcope/varcope1_flirt_merged_maths.nii.gz
# 220124-01:11:52,231 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 27.16/27.96, Free processors: 4/8.
#                      Currently running:
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220124-01:12:43,792 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2estimate".
# 220124-01:12:43,936 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2estimate".
# 220124-01:12:44,274 nipype.workflow INFO:
# 	 [Job 9] Completed (level2.level2estimate).
# 220124-01:12:44,275 nipype.workflow INFO:
# 	 [Job 20] Completed (level2.level2estimate).
# 220124-01:12:44,276 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 27.56/27.96, Free processors: 6/8.
#                      Currently running:
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220124-01:12:44,318 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/home/yc/out/fsl/hw2/level2/_contr_id_4/sinker".
# 220124-01:12:44,319 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/home/yc/out/fsl/hw2/level2/_contr_id_3/sinker".
# 220124-01:12:44,331 nipype.workflow INFO:
# 	 [Node] Running "sinker" ("nipype.interfaces.io.DataSink")
# 220124-01:12:44,332 nipype.workflow INFO:
# 	 [Node] Running "sinker" ("nipype.interfaces.io.DataSink")
# 220124-01:12:46,277 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 27.16/27.96, Free processors: 4/8.
#                      Currently running:
#                        * level2.sinker
#                        * level2.sinker
#                        * level2.level2estimate
#                        * level2.level2estimate
# 220124-01:12:47,456 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2estimate".
# 220124-01:12:48,279 nipype.workflow INFO:
# 	 [Job 31] Completed (level2.level2estimate).
# 220124-01:12:48,280 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 27.36/27.96, Free processors: 5/8.
#                      Currently running:
#                        * level2.sinker
#                        * level2.sinker
#                        * level2.level2estimate
# 220124-01:12:48,323 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/home/yc/out/fsl/hw2/level2/_contr_id_2/sinker".
# 220124-01:12:48,376 nipype.workflow INFO:
# 	 [Node] Running "sinker" ("nipype.interfaces.io.DataSink")
# 220124-01:12:50,281 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 27.16/27.96, Free processors: 4/8.
#                      Currently running:
#                        * level2.sinker
#                        * level2.sinker
#                        * level2.sinker
#                        * level2.level2estimate
# 220124-01:12:54,132 nipype.workflow INFO:
# 	 [Node] Finished "level2.sinker".
# 220124-01:12:54,150 nipype.workflow INFO:
# 	 [Node] Finished "level2.sinker".
# 220124-01:12:54,284 nipype.workflow INFO:
# 	 [Job 10] Completed (level2.sinker).
# 220124-01:12:54,285 nipype.workflow INFO:
# 	 [Job 21] Completed (level2.sinker).
# 220124-01:12:54,286 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.56/27.96, Free processors: 6/8.
#                      Currently running:
#                        * level2.sinker
#                        * level2.level2estimate
# 220124-01:12:54,470 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2estimate".
# 220124-01:12:54,964 nipype.workflow INFO:
# 	 [Node] Finished "level2.sinker".
# 220124-01:12:56,287 nipype.workflow INFO:
# 	 [Job 42] Completed (level2.level2estimate).
# 220124-01:12:56,288 nipype.workflow INFO:
# 	 [Job 32] Completed (level2.sinker).
# 220124-01:12:56,289 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 27.96/27.96, Free processors: 8/8.
# 220124-01:12:56,337 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/home/yc/out/fsl/hw2/level2/_contr_id_1/sinker".
# 220124-01:12:56,349 nipype.workflow INFO:
# 	 [Node] Running "sinker" ("nipype.interfaces.io.DataSink")
# 220124-01:12:58,289 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 27.76/27.96, Free processors: 7/8.
#                      Currently running:
#                        * level2.sinker
# 220124-01:13:00,495 nipype.workflow INFO:
# 	 [Node] Finished "level2.sinker".
# 220124-01:13:02,292 nipype.workflow INFO:
# 	 [Job 43] Completed (level2.sinker).
# 220124-01:13:02,294 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 27.96/27.96, Free processors: 8/8.
