# %% [markdown]
# # Second level GLM using Nipype FSL
#
# Notebook compiled by Yibei Chen
#
# In this notebook, we recreate the whole preprocess of FSL GUI using nipype code. For each nipype node, we list the corresponding fsl command from the log file. The dataset we use is a Flanker task, which can be downloaded [here](https://openneuro.org/datasets/ds000102/versions/00001).
#
# We also borrow some helps from this [document](https://nipype.readthedocs.io/en/latest/users/examples/fmri_fsl.html).

# %% [markdown]
# ## Preparation
# Import all the relevant libraries needed for the preprocessing stage.

# %%
from __future__ import print_function
from __future__ import division
from builtins import str
from builtins import range

import os, stat  # system functions
import getpass
from glob import glob

import numpy as np
from nipype import Function
import nipype.interfaces.io as nio  # Data i/o
import nipype.interfaces.fsl as fsl  # fsl
import nipype.interfaces.utility as util  # utility
import nipype.pipeline.engine as pe  # pypeline engine
import nipype.algorithms.modelgen as model  # model generation
import nipype.algorithms.rapidart as ra  # artifact detection

# %autosave 5
# Out:
# Autosaving every 5 seconds

# %% [markdown]
# Set up data path

# %%
# Get current user
user = getpass.getuser()
print('Running code as: ', user)

# Input: Set the first-level result path
data_dir = '/home/{}/out/fsl/hw2/level1_results/'.format(user)
# Output: Set path where nipype will store stepwise results
exp_dir = '/home/{}/out/fsl/hw2/'.format(user)

try:
    os.mkdir(exp_dir)
except OSError as error:
    print(error)
    
    
# Grant root write access to our output files 
os.chmod(exp_dir, os.stat(exp_dir).st_mode | ((stat.S_IRWXU | stat.S_IRWXO)))
# Out:
# Running code as:  yc
# [Errno 17] File exists: '/home/yc/out/fsl/hw2/'

# %% [markdown]
# Start the workflow

# %%
wf = pe.Workflow(name='level2', base_dir=exp_dir)
wf.config["execution"]["crashfile_format"] = "txt"

# %% [markdown]
# The following two nodes (`infosource` & `dg`) together define all inputs required for the preprocessing workflow

# %%
# we want to group the outcome by contrast not subject
contr_list = [1,2,3,4]
infosource = pe.Node(util.IdentityInterface(fields=["contr_id"]),
                  name="infosource")
infosource.iterables = [("contr_id", contr_list)]

# %%
# here we use SelectFiles, instead of DataGrabber, because the former is more flexible with formatting syntax
templates = {
    "reg_copes":"*/reg_copes/*/*/cope{contr_id}_flirt.nii.gz",
    "reg_varcopes":"*/reg_varcopes/*/*/varcope{contr_id}_flirt.nii.gz",
    "reg_masks":"*/reg_masks/*/*/*.nii.gz"
}
dg = pe.Node(interface=nio.SelectFiles(templates),
             name="selectfiles")
dg.inputs.base_directory = data_dir

wf.connect([
        (infosource, dg, [("contr_id", "contr_id")])
])

# %% [markdown]
# ## Second-level GLM
#
# Combining results from multiple runs of one subject into one

# %% [markdown]
# ### Higher-level input files preparation

# %% [markdown]
# #### Step 1: Merge registered copes & varcopes & masks
#
#
# **Corresponding FSL command:**
# ```
# /usr/local/fsl/bin/fslmerge -t mask (masks from all 52 inputs)
# /usr/local/fsl/bin/fslmerge -t cope (copes from all 52 inputs)
# /usr/local/fsl/bin/fslmerge -t varcop (varcopes from all 52 inputs)
# ```

# %%
copemerge = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="copemerge")

varcopemerge = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="varcopemerge")

maskmerge = pe.Node(
    interface=fsl.Merge(dimension='t'),
    iterfield=['in_files'],
    name="maskmerge")


def sort_copes(files):
    numelements = len(files[0])
    outfiles = []
    for i in range(numelements):
        outfiles.insert(i, [])
        for j, elements in enumerate(files):
            outfiles[i].append(elements[i])
    return outfiles



wf.connect(dg, 'reg_copes', copemerge, 'in_files')
wf.connect(dg, 'reg_varcopes', varcopemerge, 'in_files')
wf.connect(dg, 'reg_masks', maskmerge, 'in_files')

# %% [markdown]
# #### Step 2: Making mask
#
# In FSL, there are many commands about `maskunique`, which is unless for the second level. We can ignore it.
#
# **Corresponding FSL command:**
# ```
# /usr/local/fsl/bin/fslmaths mask -Tmin mask
# ```

# %%
# /usr/local/fsl/bin/fslmaths mask -Tmin mask
minmask = pe.Node(
    interface=fsl.ImageMaths(op_string='-Tmin'),
    iterfield=['in_file'],
    name='minmask')

wf.connect(maskmerge, 'merged_file', minmask, 'in_file')

# %% [markdown]
# #### Step 3: Masking copes & varcopes
#
# **Corresponding FSL command:**
#
# we have four contrasts so the following commands repeat four times
#
# ```
# /usr/local/fsl/bin/fslmaths cope1 -mas mask cope1
# /usr/local/fsl/bin/fslmaths varcope1 -mas mask varcope1
# ```

# %%
maskcope = pe.Node(
    interface=fsl.ImageMaths(op_string='-mas'),
    iterfield=['in_file', 'in_file2'],
    name='maskcope')

maskvarcope = pe.Node(
    interface=fsl.ImageMaths(op_string='-mas'),
    iterfield=['in_file', 'in_file2'],
    name='maskvarcope')

wf.connect(copemerge, 'merged_file', maskcope, 'in_file')
wf.connect(minmask, 'out_file', maskcope, 'in_file2')
wf.connect(varcopemerge, 'merged_file', maskvarcope, 'in_file')
wf.connect(minmask, 'out_file', maskvarcope, 'in_file2')

# %% [markdown]
# ### Set up second-level contrasts and fixed-effects

# %%
def get_contrasts_l2(in_files):
    import numpy as np
    total = len(in_files)
    print(in_files)
    print(total)
    n_sub = 26
    ev_list = ['ev'+str(x) for x in range(1,n_sub+1)]
    weight_mtx = np.zeros((26,26))
    weight_mtx = weight_mtx.astype(np.float64)
    np.fill_diagonal(weight_mtx,1.)
    contr = ['','T',ev_list,list(weight_mtx[0])]
    contr_lst = np.tile(contr, (n_sub, 1))
    contr_lst = [list(x) for x in contr_lst]
    for i in range(n_sub):
        contr_lst[i][3] = list(weight_mtx[i])

    reg_dict = {k:None for k in ev_list}
    for k in reg_dict.keys():
        start_lst = [0.0] * total
        idx = ev_list.index(k)
        start_idx = idx*2
        end_idx = idx*2 + 1
        start_lst[start_idx] = 1.
        start_lst[end_idx] = 1.
        reg_dict[k] = start_lst
        
    return contr_lst, reg_dict

contrastgen_l2 = pe.Node(util.Function(input_names=['in_files'],
                                    output_names=['contr_lst', 'reg_dict'],
                                    function=get_contrasts_l2),
                      iterfield=['in_files'],
                      name='contrastgen_l2')

wf.connect(dg,'reg_copes', contrastgen_l2, 'in_files')

# %% [markdown]
# Nipype recommands using [L2Model](https://nipype.readthedocs.io/en/latest/api/generated/nipype.interfaces.fsl.model.html#l2model), which only works for the single subject. It takes the number of runs (copes at the first level) as input and does estimations for subject one by one.
# Instead, we use [MultipleRegressDesign](https://nipype.readthedocs.io/en/latest/api/generated/nipype.interfaces.fsl.model.html#multipleregressdesign). As it's name indicates, this one can deal with multiple predictors (subjects) at the same time.

# %%
level2model = pe.Node(interface=fsl.MultipleRegressDesign(),
                      name='l2model')

wf.connect([(contrastgen_l2, level2model, [('contr_lst','contrasts'),
                                        ('reg_dict','regressors')])])

# %%
level2estimate = pe.Node(
    interface=fsl.FLAMEO(run_mode='fe'),
    name="level2estimate",
    iterfield=['cope_file', 'var_cope_file'])

wf.connect([
    (maskcope, level2estimate, [('out_file', 'cope_file')]),
    (maskvarcope, level2estimate, [('out_file', 'var_cope_file')]),
    (minmask, level2estimate, [('out_file', 'mask_file')]),
    (level2model, level2estimate, [('design_mat', 'design_file'),
                                   ('design_con', 't_con_file'), 
                                   ('design_grp', 'cov_split_file')]),
])

# %%
datasink = pe.Node(nio.DataSink(), name='sinker')
datasink.inputs.base_directory=os.path.join(exp_dir, "level2_results")

int2string = lambda x: 'contrast_'+str(x)
    
wf.connect(infosource, ('contr_id',int2string), datasink, 'container')
wf.connect([(level2estimate, datasink, [('stats_dir', 'stats_dir')])])

# %%
# Run Workflow
wf.run(plugin="MultiProc", plugin_args={"n_procs": 8})
# Out:
# 211208-05:42:38,303 nipype.workflow INFO:
# 	 Workflow level2 settings: ['check', 'execution', 'logging', 'monitoring']
# 211208-05:42:38,349 nipype.workflow INFO:
# 	 Running in parallel.
# 211208-05:42:38,352 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 27.96/27.96, Free processors: 8/8.
# 211208-05:42:38,426 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles" in "/home/yc/out/fsl/hw2/level2/_contr_id_4/selectfiles".
# 211208-05:42:38,429 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles" in "/home/yc/out/fsl/hw2/level2/_contr_id_3/selectfiles".
# 211208-05:42:38,431 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles" in "/home/yc/out/fsl/hw2/level2/_contr_id_2/selectfiles".
# 211208-05:42:38,434 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.selectfiles" in "/home/yc/out/fsl/hw2/level2/_contr_id_1/selectfiles".
# 211208-05:42:38,481 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 211208-05:42:38,508 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 211208-05:42:38,511 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 211208-05:42:38,566 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 211208-05:42:38,717 nipype.workflow INFO:
# 	 [Node] Finished "level2.selectfiles".
# 211208-05:42:38,727 nipype.workflow INFO:
# 	 [Node] Finished "level2.selectfiles".
# 211208-05:42:38,738 nipype.workflow INFO:
# 	 [Node] Finished "level2.selectfiles".
# 211208-05:42:38,740 nipype.workflow INFO:
# 	 [Node] Finished "level2.selectfiles".
# 211208-05:42:40,354 nipype.workflow INFO:
# 	 [Job 0] Completed (level2.selectfiles).
# 211208-05:42:40,356 nipype.workflow INFO:
# 	 [Job 14] Completed (level2.selectfiles).
# 211208-05:42:40,358 nipype.workflow INFO:
# 	 [Job 28] Completed (level2.selectfiles).
# 211208-05:42:40,359 nipype.workflow INFO:
# 	 [Job 42] Completed (level2.selectfiles).
# 211208-05:42:40,360 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 16 jobs ready. Free memory (GB): 27.96/27.96, Free processors: 8/8.
# 211208-05:42:40,422 nipype.workflow INFO:
# 	 [Job 1] Cached (level2.contrastgen_l2).
# 211208-05:42:40,461 nipype.workflow INFO:
# 	 [Job 3] Cached (level2.maskmerge).
# 211208-05:42:40,467 nipype.workflow INFO:
# 	 [Job 6] Cached (level2.varcopemerge).
# 211208-05:42:40,473 nipype.workflow INFO:
# 	 [Job 9] Cached (level2.copemerge).
# 211208-05:42:40,479 nipype.workflow INFO:
# 	 [Job 15] Cached (level2.contrastgen_l2).
# 211208-05:42:40,486 nipype.workflow INFO:
# 	 [Job 17] Cached (level2.maskmerge).
# 211208-05:42:40,492 nipype.workflow INFO:
# 	 [Job 20] Cached (level2.varcopemerge).
# 211208-05:42:40,497 nipype.workflow INFO:
# 	 [Job 23] Cached (level2.copemerge).
# 211208-05:42:42,355 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 12 jobs ready. Free memory (GB): 27.96/27.96, Free processors: 8/8.
# 211208-05:42:42,431 nipype.workflow INFO:
# 	 [Job 2] Cached (level2.l2model).
# 211208-05:42:42,435 nipype.workflow INFO:
# 	 [Job 4] Cached (level2.minmask).
# 211208-05:42:42,463 nipype.workflow INFO:
# 	 [Job 16] Cached (level2.l2model).
# 211208-05:42:42,467 nipype.workflow INFO:
# 	 [Job 18] Cached (level2.minmask).
# 211208-05:42:42,473 nipype.workflow INFO:
# 	 [Job 29] Cached (level2.contrastgen_l2).
# 211208-05:42:42,499 nipype.workflow INFO:
# 	 [Job 31] Cached (level2.maskmerge).
# 211208-05:42:42,504 nipype.workflow INFO:
# 	 [Job 34] Cached (level2.varcopemerge).
# 211208-05:42:42,514 nipype.workflow INFO:
# 	 [Job 37] Cached (level2.copemerge).
# 211208-05:42:44,419 nipype.workflow INFO:
# 	 [Job 5] Cached (level2.masksplit).
# 211208-05:42:44,433 nipype.workflow INFO:
# 	 [Job 7] Cached (level2.maskvarcope).
# 211208-05:42:44,449 nipype.workflow INFO:
# 	 [Job 10] Cached (level2.maskcope).
# 211208-05:42:44,468 nipype.workflow INFO:
# 	 [Job 19] Cached (level2.masksplit).
# 211208-05:42:44,488 nipype.workflow INFO:
# 	 [Job 21] Cached (level2.maskvarcope).
# 211208-05:42:44,500 nipype.workflow INFO:
# 	 [Job 24] Cached (level2.maskcope).
# 211208-05:42:44,534 nipype.workflow INFO:
# 	 [Job 30] Cached (level2.l2model).
# 211208-05:42:44,538 nipype.workflow INFO:
# 	 [Job 32] Cached (level2.minmask).
# 211208-05:42:46,357 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 13 jobs ready. Free memory (GB): 27.96/27.96, Free processors: 8/8.
# 211208-05:42:46,420 nipype.workflow INFO:
# 	 [Job 8] Cached (level2.varcopesplit).
# 211208-05:42:46,423 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2estimate" in "/home/yc/out/fsl/hw2/level2/_contr_id_4/level2estimate".
# 211208-05:42:46,442 nipype.workflow INFO:
# 	 [Job 13] Cached (level2.copesplit).
# 211208-05:42:46,454 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.fsl.model.FLAMEO"), a CommandLine Interface with command:
# flameo --copefile=/home/yc/out/fsl/hw2/level2/_contr_id_4/maskcope/cope4_flirt_merged_maths.nii.gz --covsplitfile=/home/yc/out/fsl/hw2/level2/_contr_id_4/l2model/design.grp --designfile=/home/yc/out/fsl/hw2/level2/_contr_id_4/l2model/design.mat --ld=stats --maskfile=/home/yc/out/fsl/hw2/level2/_contr_id_4/minmask/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged_maths.nii.gz --runmode=fe --tcontrastsfile=/home/yc/out/fsl/hw2/level2/_contr_id_4/l2model/design.con --varcopefile=/home/yc/out/fsl/hw2/level2/_contr_id_4/maskvarcope/varcope4_flirt_merged_maths.nii.gz
# 211208-05:42:46,463 nipype.workflow INFO:
# 	 [Job 22] Cached (level2.varcopesplit).
# 211208-05:42:46,490 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 211208-05:42:46,494 nipype.workflow INFO:
# 	 [Job 27] Cached (level2.copesplit).
# 211208-05:42:46,516 nipype.workflow INFO:
# 	 [Job 33] Cached (level2.masksplit).
# 211208-05:42:46,494 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2estimate" in "/home/yc/out/fsl/hw2/level2/_contr_id_3/level2estimate".
# 211208-05:42:46,540 nipype.workflow INFO:
# 	 [Job 35] Cached (level2.maskvarcope).
# 211208-05:42:46,540 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 211208-05:42:46,969 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.fsl.model.FLAMEO"), a CommandLine Interface with command:
# flameo --copefile=/home/yc/out/fsl/hw2/level2/_contr_id_3/maskcope/cope3_flirt_merged_maths.nii.gz --covsplitfile=/home/yc/out/fsl/hw2/level2/_contr_id_3/l2model/design.grp --designfile=/home/yc/out/fsl/hw2/level2/_contr_id_3/l2model/design.mat --ld=stats --maskfile=/home/yc/out/fsl/hw2/level2/_contr_id_3/minmask/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged_maths.nii.gz --runmode=fe --tcontrastsfile=/home/yc/out/fsl/hw2/level2/_contr_id_3/l2model/design.con --varcopefile=/home/yc/out/fsl/hw2/level2/_contr_id_3/maskvarcope/varcope3_flirt_merged_maths.nii.gz
# 211208-05:42:48,358 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 6 jobs ready. Free memory (GB): 27.56/27.96, Free processors: 6/8.
#                      Currently running:
#                        * level2.level2estimate
#                        * level2.level2estimate
# 211208-05:42:48,419 nipype.workflow INFO:
# 	 [Job 36] Cached (level2.varcopesplit).
# 211208-05:42:48,441 nipype.workflow INFO:
# 	 [Job 38] Cached (level2.maskcope).
# 211208-05:42:48,450 nipype.workflow INFO:
# 	 [Job 43] Cached (level2.contrastgen_l2).
# 211208-05:42:48,459 nipype.workflow INFO:
# 	 [Job 45] Cached (level2.maskmerge).
# 211208-05:42:48,467 nipype.workflow INFO:
# 	 [Job 48] Cached (level2.varcopemerge).
# 211208-05:42:48,474 nipype.workflow INFO:
# 	 [Job 51] Cached (level2.copemerge).
# 211208-05:42:50,359 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 27.56/27.96, Free processors: 6/8.
#                      Currently running:
#                        * level2.level2estimate
#                        * level2.level2estimate
# 211208-05:42:50,426 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 211208-05:42:50,430 nipype.workflow INFO:
# 	 [Job 41] Cached (level2.copesplit).
# 211208-05:42:50,471 nipype.workflow INFO:
# 	 [Job 44] Cached (level2.l2model).
# 211208-05:42:50,474 nipype.workflow INFO:
# 	 [Job 46] Cached (level2.minmask).
# 211208-05:42:50,429 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2estimate" in "/home/yc/out/fsl/hw2/level2/_contr_id_2/level2estimate".
# 211208-05:42:50,476 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 211208-05:42:50,740 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.fsl.model.FLAMEO"), a CommandLine Interface with command:
# flameo --copefile=/home/yc/out/fsl/hw2/level2/_contr_id_2/maskcope/cope2_flirt_merged_maths.nii.gz --covsplitfile=/home/yc/out/fsl/hw2/level2/_contr_id_2/l2model/design.grp --designfile=/home/yc/out/fsl/hw2/level2/_contr_id_2/l2model/design.mat --ld=stats --maskfile=/home/yc/out/fsl/hw2/level2/_contr_id_2/minmask/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged_maths.nii.gz --runmode=fe --tcontrastsfile=/home/yc/out/fsl/hw2/level2/_contr_id_2/l2model/design.con --varcopefile=/home/yc/out/fsl/hw2/level2/_contr_id_2/maskvarcope/varcope2_flirt_merged_maths.nii.gz
# 211208-05:42:52,361 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 3 jobs ready. Free memory (GB): 27.36/27.96, Free processors: 5/8.
#                      Currently running:
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 211208-05:42:52,408 nipype.workflow INFO:
# 	 [Job 47] Cached (level2.masksplit).
# 211208-05:42:52,412 nipype.workflow INFO:
# 	 [Job 49] Cached (level2.maskvarcope).
# 211208-05:42:52,417 nipype.workflow INFO:
# 	 [Job 52] Cached (level2.maskcope).
# 211208-05:42:54,410 nipype.workflow INFO:
# 	 [Job 50] Cached (level2.varcopesplit).
# 211208-05:42:54,416 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 211208-05:42:54,421 nipype.workflow INFO:
# 	 [Job 55] Cached (level2.copesplit).
# 211208-05:42:54,420 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.level2estimate" in "/home/yc/out/fsl/hw2/level2/_contr_id_1/level2estimate".
# 211208-05:42:54,447 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.level2estimate".
# 211208-05:42:54,654 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.fsl.model.FLAMEO"), a CommandLine Interface with command:
# flameo --copefile=/home/yc/out/fsl/hw2/level2/_contr_id_1/maskcope/cope1_flirt_merged_maths.nii.gz --covsplitfile=/home/yc/out/fsl/hw2/level2/_contr_id_1/l2model/design.grp --designfile=/home/yc/out/fsl/hw2/level2/_contr_id_1/l2model/design.mat --ld=stats --maskfile=/home/yc/out/fsl/hw2/level2/_contr_id_1/minmask/sub-01_task-flanker_run-1_bold_dtype_mcf_bet_thresh_dil_flirt_merged_maths.nii.gz --runmode=fe --tcontrastsfile=/home/yc/out/fsl/hw2/level2/_contr_id_1/l2model/design.con --varcopefile=/home/yc/out/fsl/hw2/level2/_contr_id_1/maskvarcope/varcope1_flirt_merged_maths.nii.gz
# 211208-05:42:56,364 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 27.16/27.96, Free processors: 4/8.
#                      Currently running:
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
#                        * level2.level2estimate
# 211208-05:43:51,277 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2estimate".
# 211208-05:43:51,427 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2estimate".
# 211208-05:43:52,413 nipype.workflow INFO:
# 	 [Job 11] Completed (level2.level2estimate).
# 211208-05:43:52,414 nipype.workflow INFO:
# 	 [Job 25] Completed (level2.level2estimate).
# 211208-05:43:52,416 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 27.56/27.96, Free processors: 6/8.
#                      Currently running:
#                        * level2.level2estimate
#                        * level2.level2estimate
# 211208-05:43:52,469 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.sinker".
# 211208-05:43:52,472 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/home/yc/out/fsl/hw2/level2/_contr_id_4/sinker".
# 211208-05:43:52,474 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.sinker".
# 211208-05:43:52,474 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.sinker".
# 211208-05:43:52,477 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/home/yc/out/fsl/hw2/level2/_contr_id_3/sinker".
# 211208-05:43:52,479 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.sinker".
# 211208-05:43:52,705 nipype.workflow INFO:
# 	 [Node] Running "sinker" ("nipype.interfaces.io.DataSink")
# 211208-05:43:53,152 nipype.workflow INFO:
# 	 [Node] Running "sinker" ("nipype.interfaces.io.DataSink")
# 211208-05:43:54,415 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 27.16/27.96, Free processors: 4/8.
#                      Currently running:
#                        * level2.sinker
#                        * level2.sinker
#                        * level2.level2estimate
#                        * level2.level2estimate
# 211208-05:43:57,7 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2estimate".
# 211208-05:43:58,419 nipype.workflow INFO:
# 	 [Job 39] Completed (level2.level2estimate).
# 211208-05:43:58,420 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 27.36/27.96, Free processors: 5/8.
#                      Currently running:
#                        * level2.sinker
#                        * level2.sinker
#                        * level2.level2estimate
# 211208-05:43:58,474 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.sinker".
# 211208-05:43:58,477 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/home/yc/out/fsl/hw2/level2/_contr_id_2/sinker".
# 211208-05:43:58,490 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.sinker".
# 211208-05:43:58,888 nipype.workflow INFO:
# 	 [Node] Running "sinker" ("nipype.interfaces.io.DataSink")
# 211208-05:43:59,980 nipype.workflow INFO:
# 	 [Node] Finished "level2.level2estimate".
# 211208-05:44:00,421 nipype.workflow INFO:
# 	 [Job 53] Completed (level2.level2estimate).
# 211208-05:44:00,422 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 27.36/27.96, Free processors: 5/8.
#                      Currently running:
#                        * level2.sinker
#                        * level2.sinker
#                        * level2.sinker
# 211208-05:44:00,514 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.sinker".
# 211208-05:44:00,517 nipype.workflow INFO:
# 	 [Node] Setting-up "level2.sinker" in "/home/yc/out/fsl/hw2/level2/_contr_id_1/sinker".
# 211208-05:44:00,529 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "level2.sinker".
# 211208-05:44:00,973 nipype.workflow INFO:
# 	 [Node] Running "sinker" ("nipype.interfaces.io.DataSink")
# 211208-05:44:02,423 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 27.16/27.96, Free processors: 4/8.
#                      Currently running:
#                        * level2.sinker
#                        * level2.sinker
#                        * level2.sinker
#                        * level2.sinker
# 211208-05:44:03,804 nipype.workflow INFO:
# 	 [Node] Finished "level2.sinker".
# 211208-05:44:04,425 nipype.workflow INFO:
# 	 [Job 26] Completed (level2.sinker).
# 211208-05:44:04,426 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 27.36/27.96, Free processors: 5/8.
#                      Currently running:
#                        * level2.sinker
#                        * level2.sinker
#                        * level2.sinker
# 211208-05:44:04,486 nipype.workflow INFO:
# 	 [Node] Finished "level2.sinker".
# 211208-05:44:06,427 nipype.workflow INFO:
# 	 [Job 12] Completed (level2.sinker).
# 211208-05:44:06,428 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 27.56/27.96, Free processors: 6/8.
#                      Currently running:
#                        * level2.sinker
#                        * level2.sinker
# 211208-05:44:06,757 nipype.workflow INFO:
# 	 [Node] Finished "level2.sinker".
# 211208-05:44:07,934 nipype.workflow INFO:
# 	 [Node] Finished "level2.sinker".
# 211208-05:44:08,429 nipype.workflow INFO:
# 	 [Job 40] Completed (level2.sinker).
# 211208-05:44:08,430 nipype.workflow INFO:
# 	 [Job 54] Completed (level2.sinker).
# 211208-05:44:08,432 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 27.96/27.96, Free processors: 8/8.
